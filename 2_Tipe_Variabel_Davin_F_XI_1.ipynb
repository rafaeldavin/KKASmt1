# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeldavin/KKASmt1/blob/main/2_Tipe_Variabel_Davin_F_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama : Rafael Davin Fachrial
# kelas : XI-1
# no absen : 31

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "rafaeldavin2025@gmail.com"
print(email_user_1)
# Out:
# rafaeldavin2025@gmail.com

# %%
sabun_lifebuoy = 15000
print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
# tidak boleh menggunakan spasi
nama siswa = "Afa"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-915796677.py", line 3
#     nama siswa = "Afa"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka
1_nama_siswa = "Afa"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-3498618216.py", line 2
#     1_nama_siswa = "Afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
# penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4026801131.py in <cell line: 0>()
#       2 nama_siswa_1 = "Afa"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di bahasa python

prin = "afa"

print(prin)
# Out:
# afa

# %%
end =  "Naufal"
print(end)
# Out:
# Naufal

# %%
# Deskriptif

_ = "Favian"

print(_)
# Out:
# Favian

# %%
# tidak boleh pakai kata kunci python
# kalau error, harus disconnect
# print = "Devin"

# print(print)

# %% [markdown]
# # Assignment

# %% [markdown]
# ## Single Assignment

# %%
nama_siswa_1 = "Dhapne"
nama_siswa_2 = "Farel"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ## Multiple Assignment

# %%
nama_siswa_3, nama_siswa_4 = "sada", "selo"
print(nama_siswa_3)
print(nama_siswa_4)
# Out:
# sada
# selo

# %% [markdown]
# ## Assign ke banyak variabel sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ## perubahan nilai variabel

# %%
nilai_afa = 70

# %% [markdown]
# # Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3*

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
# simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
# simpan hasil operasi ke dalam variabel

harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel

harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_botol = banyak_botol_per_kardus*jumlah_kardus

print(total_botol)
# Out:
# 72

# %% [markdown]
# # Tipe Variabel

# %%
usia = 65
type(usia)
# Out:
# int

# %%
berat_telur = 2.5
type(berat_telur)
# Out:
# float

# %%
nama = "favi gey"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
remidi = True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# # input

# %%
panjang = 10
lebar = 5
luas = panjang * lebar
print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang * lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-840156163.py in <cell line: 0>()
# ----> 1 luas = panjang * lebar
#       2 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang= int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("masukan panjang persegi panjang : "))
# Out:
# masukan panjang persegi panjang : 10

# %%
panjang_2 = int(input("masukan panjang persegi panjang 2: "))
lebar_2 = int(input("masukan lebar persegi panjang 2: "))

luas_2 = panjang_2 * lebar_2

print(f"luas persegi panjang adalah {luas_2} cm^2")
# Out:
# masukan panjang persegi panjang 2: 100
# masukan lebar persegi panjang 2: 70
# luas persegi panjang adalah 7000 cm^2

# %%
panjang_balok = int(input("masukan panjang balok: "))
lebar_balok = int(input("masukan lebar balok: "))
tinggi_balok = int(input("masukan tinggi balok: "))

volume_balok = panjang_balok * lebar_balok * tinggi_balok

print(f"volume persegi panjang adalah {volume_balok} cm^3")
# Out:
# masukan panjang balok: 10
# masukan lebar balok: 6
# masukan tinggi balok: 2
# volume persegi panjang adalah 120 cm^3

# %%
jari_jari_tabung = float(input("silahkan masukan jari jari tabung: "))
tinggi_tabung = float(input("silahkan masukan tinggi tabung: "))
phi = 3.14

volume_tabung = phi * jari_jari_tabung**2 * tinggi_tabung

print(f"volume tabung adalah {volume_tabung} cm^3")
# Out:
# silahkan masukan jari jari tabung: 7
# silahkan masukan tinggi tabung: 13
# volume tabung adalah 2000.1800000000003 cm^3

# %% [markdown]
# #Operator perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 8)
# Out:
# True

# %%
print(1 != 1)
# Out:
# False

# %%
a = 10
b = 20
c = 30
print(a > c)
# Out:
# False

# %% [markdown]
# # Operator logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165
print(125>=iq_min and 170>=tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170
print(iq_afa>=iq_min and tinggi_afa>=tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
berat_min = 50
umur_max = 25
tinggi_farel = 170
berat_farel = 55
umur_farel = 23
print(tinggi_farel>=tinggi_min and berat_farel>=berat_min and umur_farel<=umur_max)
# Out:
# True
